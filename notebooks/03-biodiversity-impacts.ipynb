# %% [markdown]
# # Session 7: Biodiversity Impacts & Raster Analysis
#
# **Goal:** Assess the ecological impact of data centers by overlaying them with biodiversity data (MOBI Species Richness).
#
# Datasets:
# 1.  **Data Centers**: Locations from Cloud Regions.
# 2.  **MOBI Species Richness**: A raster dataset representing species richness (Taxonomic Groups) derived from MaxEnt models.

# %% [markdown]
# ### Action Item 1: Setup Environment
#
# > **Prompt your Agent:**
# > "Import rasterio, rioxarray, pandas, geopandas, and ibis. Connect to a local DuckDB instance."

# %% [markdown]
# ## 1. Load Data
#
# Load data centers and the biodiversity raster.
#
# **URLs**:
# - Data Centers (CSV): `https://s3-west.nrp-nautilus.io/public-datacenters/data_centers.csv`
# - Biodiversity Raster (Tif): `https://minio.carlboettiger.info/public-mobi/mobi-species-richness.tif`
#
# ### Action Item 2: Load Data & Check CRS
#
# > **Prompt your Agent:**
# > "Load the data centers csv into an Ibis table, filtering for 'United States' and creating geometries. Load the biodiversity raster using `rioxarray`. Check and print the Coordinate Reference System (CRS) for both. If they don't match, reproject the data centers to match the raster."

# %% [markdown]
# ## 2. Extract Raster Values
#
# We want to know the species richness at each data center location.
#
# ### Action Item 3: Sample Raster
#
# > **Prompt your Agent:**
# > "Sample the species richness raster at each data center's location. Add this value as a new column to the data centers GeoDataFrame. Display the first few rows with the new column."

# %% [markdown]
# ## 3. Visualize Impacts
#
# ### Action Item 4: Visualize Distribution
#
# > **Prompt your Agent:**
# > "Create a histogram or density plot showing the distribution of species richness values for the data centers. How does it compare to the general available biodiversity?"
